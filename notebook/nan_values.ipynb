# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv("../data/train.csv")
rows_with_nan = train_df[train_df.isna().any(axis=1)]
conditions = list(rows_with_nan.columns)
conditions = conditions[1:]
print("Count of NaN values :")
for cond in conditions:
    x = rows_with_nan[cond].isna()
    print("Number of NaN values for condition ", cond, " : ", sum(x))
# Out:
# Count of NaN values :
# Number of NaN values for condition  spinal_canal_stenosis_l1_l2  :  1
# Number of NaN values for condition  spinal_canal_stenosis_l2_l3  :  1
# Number of NaN values for condition  spinal_canal_stenosis_l3_l4  :  1
# Number of NaN values for condition  spinal_canal_stenosis_l4_l5  :  1
# Number of NaN values for condition  spinal_canal_stenosis_l5_s1  :  1
# Number of NaN values for condition  left_neural_foraminal_narrowing_l1_l2  :  2
# Number of NaN values for condition  left_neural_foraminal_narrowing_l2_l3  :  2
# Number of NaN values for condition  left_neural_foraminal_narrowing_l3_l4  :  2
# Number of NaN values for condition  left_neural_foraminal_narrowing_l4_l5  :  2
# Number of NaN values for condition  left_neural_foraminal_narrowing_l5_s1  :  2
# Number of NaN values for condition  right_neural_foraminal_narrowing_l1_l2  :  8
# Number of NaN values for condition  right_neural_foraminal_narrowing_l2_l3  :  8
# Number of NaN values for condition  right_neural_foraminal_narrowing_l3_l4  :  8
# Number of NaN values for condition  right_neural_foraminal_narrowing_l4_l5  :  8
# Number of NaN values for condition  right_neural_foraminal_narrowing_l5_s1  :  8
# Number of NaN values for condition  left_subarticular_stenosis_l1_l2  :  164
# Number of NaN values for condition  left_subarticular_stenosis_l2_l3  :  82
# Number of NaN values for condition  left_subarticular_stenosis_l3_l4  :  3
# Number of NaN values for condition  left_subarticular_stenosis_l4_l5  :  3
# Number of NaN values for condition  left_subarticular_stenosis_l5_s1  :  11
# Number of NaN values for condition  right_subarticular_stenosis_l1_l2  :  161
# Number of NaN values for condition  right_subarticular_stenosis_l2_l3  :  82
# Number of NaN values for condition  right_subarticular_stenosis_l3_l4  :  2
# Number of NaN values for condition  right_subarticular_stenosis_l4_l5  :  2
# Number of NaN values for condition  right_subarticular_stenosis_l5_s1  :  7

# %%
study_ids = train_df["study_id"].values

# %%
print("Count of NaN values :")
print()
subjects_with_nans = []
nans_per_cond = np.zeros(5)
for i, cond in enumerate(conditions):
    x = rows_with_nan[cond].isna().values
    subjects_with_nans += list(study_ids[np.where(x==True)[0]])
    
    print(cond, " : ", sum(x))
# Out:
# Count of NaN values :
#
# spinal_canal_stenosis_l1_l2  :  1
# spinal_canal_stenosis_l2_l3  :  1
# spinal_canal_stenosis_l3_l4  :  1
# spinal_canal_stenosis_l4_l5  :  1
# spinal_canal_stenosis_l5_s1  :  1
# left_neural_foraminal_narrowing_l1_l2  :  2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 10
#       7 subjects_with_nans += list(study_ids[np.where(x==True)[0]])
#       9 print(cond, " : ", sum(x))
# ---> 10 nans_per_cond[i]+=sum(x)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
train_df
# Out:
#         study_id spinal_canal_stenosis_l1_l2 spinal_canal_stenosis_l2_l3  \
# 0        4003253                 Normal/Mild                 Normal/Mild
# 1        4646740                 Normal/Mild                 Normal/Mild
# 2        7143189                 Normal/Mild                 Normal/Mild
# 3        8785691                 Normal/Mild                 Normal/Mild
# 4       10728036                 Normal/Mild                 Normal/Mild
# ...          ...                         ...                         ...
# 1970  4282019580                 Normal/Mild                 Normal/Mild
# 1971  4283570761                 Normal/Mild                 Normal/Mild
# 1972  4284048608                 Normal/Mild                 Normal/Mild
# 1973  4287160193                 Normal/Mild                    Moderate
# 1974  4290709089                 Normal/Mild                 Normal/Mild
#
#      spinal_canal_stenosis_l3_l4 spinal_canal_stenosis_l4_l5  \
# 0                    Normal/Mild                 Normal/Mild
# 1                       Moderate                      Severe
# 2                    Normal/Mild                 Normal/Mild
# 3                    Normal/Mild                 Normal/Mild
# 4                    Normal/Mild                 Normal/Mild
# ...                          ...                         ...
# 1970                 Normal/Mild                 Normal/Mild
# 1971                 Normal/Mild                 Normal/Mild
# 1972                 Normal/Mild                      Severe
# 1973                 Normal/Mild                 Normal/Mild
# 1974                 Normal/Mild                 Normal/Mild
#
#      spinal_canal_stenosis_l5_s1 left_neural_foraminal_narrowing_l1_l2  \
# 0                    Normal/Mild                           Normal/Mild
# 1                    Normal/Mild                           Normal/Mild
# 2                    Normal/Mild                           Normal/Mild
# 3                    Normal/Mild                           Normal/Mild
# 4                    Normal/Mild                           Normal/Mild
# ...                          ...                                   ...
# 1970                 Normal/Mild                           Normal/Mild
# 1971                 Normal/Mild                           Normal/Mild
# 1972                 Normal/Mild                           Normal/Mild
# 1973                 Normal/Mild                           Normal/Mild
# 1974                 Normal/Mild                           Normal/Mild
#
#      left_neural_foraminal_narrowing_l2_l3  \
# 0                              Normal/Mild
# 1                              Normal/Mild
# 2                              Normal/Mild
# 3                              Normal/Mild
# 4                              Normal/Mild
# ...                                    ...
# 1970                           Normal/Mild
# 1971                           Normal/Mild
# 1972                           Normal/Mild
# 1973                           Normal/Mild
# 1974                           Normal/Mild
#
#      left_neural_foraminal_narrowing_l3_l4  \
# 0                              Normal/Mild
# 1                              Normal/Mild
# 2                              Normal/Mild
# 3                              Normal/Mild
# 4                              Normal/Mild
# ...                                    ...
# 1970                           Normal/Mild
# 1971                           Normal/Mild
# 1972                           Normal/Mild
# 1973                           Normal/Mild
# 1974                           Normal/Mild
#
#      left_neural_foraminal_narrowing_l4_l5  ...  \
# 0                                 Moderate  ...
# 1                                 Moderate  ...
# 2                              Normal/Mild  ...
# 3                                 Moderate  ...
# 4                              Normal/Mild  ...
# ...                                    ...  ...
# 1970                              Moderate  ...
# 1971                           Normal/Mild  ...
# 1972                           Normal/Mild  ...
# 1973                              Moderate  ...
# 1974                           Normal/Mild  ...
#
#      left_subarticular_stenosis_l1_l2 left_subarticular_stenosis_l2_l3  \
# 0                         Normal/Mild                      Normal/Mild
# 1                         Normal/Mild                      Normal/Mild
# 2                         Normal/Mild                      Normal/Mild
# 3                         Normal/Mild                      Normal/Mild
# 4                         Normal/Mild                      Normal/Mild
# ...                               ...                              ...
# 1970                      Normal/Mild                      Normal/Mild
# 1971                      Normal/Mild                      Normal/Mild
# 1972                      Normal/Mild                      Normal/Mild
# 1973                      Normal/Mild                           Severe
# 1974                      Normal/Mild                      Normal/Mild
#
#      left_subarticular_stenosis_l3_l4 left_subarticular_stenosis_l4_l5  \
# 0                         Normal/Mild                         Moderate
# 1                         Normal/Mild                           Severe
# 2                         Normal/Mild                      Normal/Mild
# 3                         Normal/Mild                      Normal/Mild
# 4                         Normal/Mild                      Normal/Mild
# ...                               ...                              ...
# 1970                      Normal/Mild                         Moderate
# 1971                      Normal/Mild                      Normal/Mild
# 1972                      Normal/Mild                           Severe
# 1973                         Moderate                         Moderate
# 1974                      Normal/Mild                      Normal/Mild
#
#      left_subarticular_stenosis_l5_s1 right_subarticular_stenosis_l1_l2  \
# 0                         Normal/Mild                       Normal/Mild
# 1                         Normal/Mild                       Normal/Mild
# 2                         Normal/Mild                       Normal/Mild
# 3                         Normal/Mild                       Normal/Mild
# 4                         Normal/Mild                       Normal/Mild
# ...                               ...                               ...
# 1970                      Normal/Mild                       Normal/Mild
# 1971                      Normal/Mild                       Normal/Mild
# 1972                      Normal/Mild                       Normal/Mild
# 1973                      Normal/Mild                       Normal/Mild
# 1974                      Normal/Mild                       Normal/Mild
#
#      right_subarticular_stenosis_l2_l3 right_subarticular_stenosis_l3_l4  \
# 0                          Normal/Mild                       Normal/Mild
# 1                             Moderate                          Moderate
# 2                          Normal/Mild                       Normal/Mild
# 3                          Normal/Mild                       Normal/Mild
# 4                          Normal/Mild                       Normal/Mild
# ...                                ...                               ...
# 1970                       Normal/Mild                          Moderate
# 1971                       Normal/Mild                       Normal/Mild
# 1972                       Normal/Mild                       Normal/Mild
# 1973                       Normal/Mild                          Moderate
# 1974                       Normal/Mild                       Normal/Mild
#
#      right_subarticular_stenosis_l4_l5 right_subarticular_stenosis_l5_s1
# 0                          Normal/Mild                       Normal/Mild
# 1                             Moderate                       Normal/Mild
# 2                          Normal/Mild                       Normal/Mild
# 3                          Normal/Mild                       Normal/Mild
# 4                             Moderate                       Normal/Mild
# ...                                ...                               ...
# 1970                          Moderate                          Moderate
# 1971                       Normal/Mild                       Normal/Mild
# 1972                            Severe                       Normal/Mild
# 1973                          Moderate                       Normal/Mild
# 1974                       Normal/Mild                       Normal/Mild
#
# [1975 rows x 26 columns]

# %%
train_df = pd.read_csv("../data/train.csv")
train_df = train_df.dropna()
text2int = {"Normal/Mild": 0, "Moderate": 1, "Severe":2}
train_df = train_df.replace(text2int)


# train_df = train_df[["study_id",
#                     "left_neural_foraminal_narrowing_l1_l2",
#                     "left_neural_foraminal_narrowing_l2_l3",
#                     "left_neural_foraminal_narrowing_l3_l4",
#                     "left_neural_foraminal_narrowing_l4_l5",
#                     "left_neural_foraminal_narrowing_l5_s1",
#                     "right_neural_foraminal_narrowing_l1_l2",
#                     "right_neural_foraminal_narrowing_l2_l3",
#                     "right_neural_foraminal_narrowing_l3_l4",
#                     "right_neural_foraminal_narrowing_l4_l5",
#                     "right_neural_foraminal_narrowing_l5_s1"]]

df = pd.DataFrame(train_df[["left_neural_foraminal_narrowing_l1_l2",
                            "left_neural_foraminal_narrowing_l2_l3",
                            "left_neural_foraminal_narrowing_l3_l4",
                            "left_neural_foraminal_narrowing_l4_l5",
                            "left_neural_foraminal_narrowing_l5_s1",
                            "right_neural_foraminal_narrowing_l1_l2",
                            "right_neural_foraminal_narrowing_l2_l3",
                            "right_neural_foraminal_narrowing_l3_l4",
                            "right_neural_foraminal_narrowing_l4_l5",
                            "right_neural_foraminal_narrowing_l5_s1"]].sum(axis=1))

df.rename(columns={0: "count"}, inplace=True)
idx = np.where(df.values[:, 0]<=5)
exclude = np.random.choice(idx[0], size=500, replace=False)
exclude = list(train_df.iloc[exclude]["study_id"].values)

# %%
train_sub = train_df.filter(regex="_subarticular_|study_id")

# %%
rows_with_2 = train_sub[train_sub.isin([2]).any(axis=1)]

# %%
rows_with_2
# Out:
#         study_id  left_subarticular_stenosis_l1_l2  \
# 1        4646740                                 0
# 8       22191399                                 0
# 10      29931867                                 0
# 12      38281420                                 0
# 13      40745534                                 0
# ...          ...                               ...
# 1967  4279833491                                 0
# 1968  4279881930                                 0
# 1969  4279958262                                 0
# 1972  4284048608                                 0
# 1973  4287160193                                 0
#
#       left_subarticular_stenosis_l2_l3  left_subarticular_stenosis_l3_l4  \
# 1                                    0                                 0
# 8                                    0                                 0
# 10                                   0                                 1
# 12                                   0                                 0
# 13                                   0                                 1
# ...                                ...                               ...
# 1967                                 0                                 0
# 1968                                 2                                 2
# 1969                                 2                                 2
# 1972                                 0                                 0
# 1973                                 2                                 1
#
#       left_subarticular_stenosis_l4_l5  left_subarticular_stenosis_l5_s1  \
# 1                                    2                                 0
# 8                                    1                                 1
# 10                                   1                                 1
# 12                                   0                                 0
# 13                                   2                                 1
# ...                                ...                               ...
# 1967                                 2                                 0
# 1968                                 2                                 0
# 1969                                 1                                 2
# 1972                                 2                                 0
# 1973                                 1                                 0
#
#       right_subarticular_stenosis_l1_l2  right_subarticular_stenosis_l2_l3  \
# 1                                     0                                  1
# 8                                     0                                  0
# 10                                    1                                  2
# 12                                    0                                  1
# 13                                    0                                  0
# ...                                 ...                                ...
# 1967                                  0                                  0
# 1968                                  1                                  1
# 1969                                  0                                  2
# 1972                                  0                                  0
# 1973                                  0                                  0
#
#       right_subarticular_stenosis_l3_l4  right_subarticular_stenosis_l4_l5  \
# 1                                     1                                  1
# 8                                     0                                  2
# 10                                    2                                  1
# 12                                    1                                  2
# 13                                    1                                  2
# ...                                 ...                                ...
# 1967                                  0                                  2
# 1968                                  2                                  2
# 1969                                  2                                  2
# 1972                                  0                                  2
# 1973                                  1                                  1
#
#       right_subarticular_stenosis_l5_s1
# 1                                     0
# 8                                     1
# 10                                    2
# 12                                    2
# 13                                    0
# ...                                 ...
# 1967                                  0
# 1968                                  0
# 1969                                  1
# 1972                                  0
# 1973                                  0
#
# [722 rows x 11 columns]
